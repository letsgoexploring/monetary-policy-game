# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import statsmodels.api as sm
import scipy.stats as stats
# %matplotlib inline
plt.rcParams.update({'font.size': 15})
figsize=(12,8)
# Out:
# /Users/bcjenkin/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# Load data from dual mandate session: May 2016
data1 = pd.read_excel('160531_1424.xlsx',skiprows=2)
data2 = pd.read_excel('160531_1518.xlsx',skiprows=2)

# Drop rows with missing data and remove irrelevant columns
for i in data1.index:
    if type(data1['Period'][i]) == str:
        data1.loc[i,'Period'] = np.nan
        
for i in data2.index:
    if type(data2['Period'][i]) == str:
        data2.loc[i,'Period'] = np.nan
        
        
data1 = data1.dropna()
data1['Session'] = 1
data1 = data1[['Period','Subject','Group','Session','epsilon','r','piActual','piE','piEAvg','y','score']]
data1 = data1.astype(float)
data1['CB'] = data1['piE'] == -1

data2 = data2.dropna()
data2['Session'] = 2
data2 = data2[['Period','Subject','Group','Session','epsilon','r','piActual','piE','piEAvg','y','score']]
data2 = data2.astype(float)
data2['CB'] = data2['piE'] == -1

data2['Subject']  = data2['Subject']+30
data2['Group']  = data2['Group']+6


# Merge and sort
data_dual = data1.copy()
data_dual = data_dual.append(data2)

data_dual = data_dual.sort_values(['Period','Group','CB'],ascending=[True,True,False])
data_dual = data_dual.reset_index(drop=True)

data_dual = data_dual[data_dual.Period<11]

# Print top and bottom
print(data_dual[['Period','Subject','Group','Session','CB','epsilon','piActual','piE']].head(10))
print('\n',data_dual[['Period','Subject','Group','Session','CB','epsilon','piActual','piE']].tail(10))


lambd_dual = 0.1
alpha = 2
beta  = 1
kappa = 0.25
piStar = 2.5

data_dual['rOpt'] = alpha / beta - kappa/beta/(kappa**2 + lambd_dual)*(2.5 -data_dual['piEAvg'] )  + 1/beta*data_dual['epsilon']
data_dual['rRE'] = alpha / beta + 1/beta*data_dual['epsilon']
data_dual['yOpt'] = alpha - beta * data_dual['rOpt'] + data_dual['epsilon']
data_dual['yRE'] = alpha - beta * data_dual['rRE'] + data_dual['epsilon']
data_dual['piOpt'] = data_dual['piEAvg'] + kappa *data_dual['yOpt']
data_dual['piRE'] = 2.5 + kappa *data_dual['yRE']
data_dual['Error'] = data_dual['piEAvg'] - data_dual['piActual']
data_dual['Zero'] = 0
# Out:
#    Period  Subject  Group  Session     CB   epsilon  piActual   piE
# 0     1.0     16.0    1.0      1.0   True -1.238111  1.577972 -1.00
# 1     1.0      4.0    1.0      1.0  False -1.238111  1.577972  2.00
# 2     1.0     14.0    1.0      1.0  False -1.238111  1.577972  2.50
# 3     1.0     15.0    1.0      1.0  False -1.238111  1.577972  2.25
# 4     1.0     27.0    1.0      1.0  False -1.238111  1.577972  1.80
# 5     1.0     10.0    2.0      1.0   True -1.238111  2.857972 -1.00
# 6     1.0     18.0    2.0      1.0  False -1.238111  2.857972  2.00
# 7     1.0     23.0    2.0      1.0  False -1.238111  2.857972  2.50
# 8     1.0     29.0    2.0      1.0  False -1.238111  2.857972  5.00
# 9     1.0     30.0    2.0      1.0  False -1.238111  2.857972  1.20
#
#       Period  Subject  Group  Session     CB   epsilon  piActual   piE
# 540    10.0     48.0   10.0      2.0   True -0.720466  5.119884  -1.0
# 541    10.0     37.0   10.0      2.0  False -0.720466  5.119884   5.2
# 542    10.0     47.0   10.0      2.0  False -0.720466  5.119884   5.0
# 543    10.0     49.0   10.0      2.0  False -0.720466  5.119884   5.0
# 544    10.0     55.0   10.0      2.0  False -0.720466  5.119884   5.0
# 545    10.0     41.0   11.0      2.0   True -0.720466  8.244884  -1.0
# 546    10.0     35.0   11.0      2.0  False -0.720466  8.244884  13.7
# 547    10.0     38.0   11.0      2.0  False -0.720466  8.244884   7.5
# 548    10.0     40.0   11.0      2.0  False -0.720466  8.244884   9.0
# 549    10.0     44.0   11.0      2.0  False -0.720466  8.244884   8.5

# %%
# Load data from inflation targeting session: May 2017
data1 = pd.read_excel('170531_1413.xlsx',skiprows=2)
data2 = pd.read_excel('170531_1534.xlsx',skiprows=2)

# Drop rows with missing data and remove irrelevant columns
for i in data1.index:
    if type(data1['Period'][i]) == str:
        data1.loc[i,'Period'] = np.nan
        
for i in data2.index:
    if type(data2['Period'][i]) == str:
        data2.loc[i,'Period'] = np.nan
        
        
data1 = data1.dropna()
data1['Session'] = 1
data1 = data1[['Period','Subject','Group','Session','epsilon','r','piActual','piE','piEAvg','y','score']]
data1 = data1.astype(float)
data1['CB'] = data1['piE'] == -1

data2 = data2.dropna()
data2['Session'] = 2
data2 = data2[['Period','Subject','Group','Session','epsilon','r','piActual','piE','piEAvg','y','score']]
data2 = data2.astype(float)
data2['CB'] = data2['piE'] == -1

data2['Subject']  = data2['Subject']+30
data2['Group']  = data2['Group']+6


# Merge and sort
data_target = data1.copy()
data_target = data_target.append(data2)

data_target = data_target.sort_values(['Period','Group','CB'],ascending=[True,True,False])
data_target = data_target.reset_index(drop=True)

# Print top and bottom
print(data_target[['Period','Subject','Group','Session','CB','epsilon','piActual','piE']].head(10))
print('\n',data_target[['Period','Subject','Group','Session','CB','epsilon','piActual','piE']].tail(10))

lambd_target = 0
alpha = 2
beta  = 1
kappa = 0.25

data_target['rOpt'] = alpha / beta - kappa/beta/(kappa**2 + lambd_target)*(2.5 -data_target['piEAvg'] )  + 1/beta*data_target['epsilon']
data_target['rRE'] = alpha / beta + 1/beta*data_target['epsilon']
data_target['yOpt'] = alpha - beta * data_target['rOpt'] + data_target['epsilon']
data_target['yRE'] = alpha - beta * data_target['rRE'] + data_target['epsilon']
data_target['piOpt'] = data_target['piEAvg'] + kappa *data_target['yOpt']
data_target['piRE'] = 2.5 + kappa *data_target['yRE']
data_target['Error'] = data_target['piEAvg'] - data_target['piActual']
data_target['Zero'] = 0
# Out:
#    Period  Subject  Group  Session     CB  epsilon  piActual   piE
# 0     1.0     17.0    1.0      1.0   True     0.94     3.235  -1.0
# 1     1.0      7.0    1.0      1.0  False     0.94     3.235   2.5
# 2     1.0     18.0    1.0      1.0  False     0.94     3.235   1.5
# 3     1.0     28.0    1.0      1.0  False     0.94     3.235   4.0
# 4     1.0     30.0    1.0      1.0  False     0.94     3.235   5.0
# 5     1.0     26.0    2.0      1.0   True     0.94     4.735  -1.0
# 6     1.0     14.0    2.0      1.0  False     0.94     4.735   1.5
# 7     1.0     20.0    2.0      1.0  False     0.94     4.735  14.0
# 8     1.0     23.0    2.0      1.0  False     0.94     4.735   2.0
# 9     1.0     29.0    2.0      1.0  False     0.94     4.735   1.5
#
#       Period  Subject  Group  Session     CB  epsilon  piActual   piE
# 690    10.0     44.0   13.0      2.0   True     0.61     2.810 -1.00
# 691    10.0     50.0   13.0      2.0  False     0.61     2.810  2.31
# 692    10.0     61.0   13.0      2.0  False     0.61     2.810  2.00
# 693    10.0     67.0   13.0      2.0  False     0.61     2.810  2.75
# 694    10.0     68.0   13.0      2.0  False     0.61     2.810  2.40
# 695    10.0     64.0   14.0      2.0   True     0.61     2.495 -1.00
# 696    10.0     35.0   14.0      2.0  False     0.61     2.495  3.70
# 697    10.0     56.0   14.0      2.0  False     0.61     2.495  2.50
# 698    10.0     59.0   14.0      2.0  False     0.61     2.495  2.50
# 699    10.0     65.0   14.0      2.0  False     0.61     2.495  6.00

# %% [markdown]
# # Plot all group-level values for each period under each regime

# %%
fig = plt.figure(figsize=(12,8))
ax0 = fig.add_subplot(1,1,1)
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax0.set_frame_on(False)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)
ax0.plot(0, 0,'-k',lw=2,alpha=0.35)
ax0.plot(0, 0,'--k',lw=4,alpha=1)
lgd = ax0.legend(['individual groups','average across groups'],fontsize=14,ncol=2,loc='upper center', bbox_to_anchor=(0.5,-0.1))

for k in data_dual['Group'].unique():
#     print(k)
    ax1.plot(np.arange(1,11),data_dual[(data_dual['Group']==k) & (data_dual['piE']==-1)].piEAvg,'k',lw=2,alpha=0.35)
    ax2.plot(np.arange(1,11),data_dual[(data_dual['Group']==k) & (data_dual['piE']==-1)].y,'k',lw=2,alpha=0.35)
    ax3.plot(np.arange(1,11),data_dual[(data_dual['Group']==k) & (data_dual['piE']==-1)].piActual,'k',lw=2,alpha=0.35)
    ax4.plot(np.arange(1,11),data_dual[(data_dual['Group']==k) & (data_dual['piE']==-1)].r,'k',lw=2,alpha=0.35)
    
ax1.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','piEAvg']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax2.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','y']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax3.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','piActual']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax4.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','r']].groupby('Period').mean(),'--k',lw=4,alpha=1)
    
ax1.set_title('Expected inflation $\pi^e$')
ax2.set_title('Output gap $y$')
ax3.set_title('Actual inflation $\pi$')
ax4.set_title('Rate interest rate $r$')

ax1.set_xlabel('Period')
ax2.set_xlabel('Period')
ax3.set_xlabel('Period')
ax4.set_xlabel('Period')

ax1.set_ylabel('Percent')
ax2.set_ylabel('Percent')
ax3.set_ylabel('Percent')
ax4.set_ylabel('Percent')

ax1.set_ylim([0,10])
ax2.set_ylim([-25,5])
ax3.set_ylim([-3,8])
ax4.set_ylim([0,25])

fig.tight_layout()


plt.savefig('fig_dual_all_groups.png',bbox_inches='tight',dpi=120)

# %%
fig = plt.figure(figsize=(12,8))
ax0 = fig.add_subplot(1,1,1)
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)


ax0.set_frame_on(False)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)
ax0.plot(0, 0,'-k',lw=2,alpha=0.35)
ax0.plot(0, 0,'--k',lw=4,alpha=1)
lgd = ax0.legend(['individual groups','average across groups'],fontsize=14,ncol=2,loc='upper center', bbox_to_anchor=(0.5,-0.1))

for k in data_target['Group'].unique():
#     print(k)
    ax1.plot(np.arange(1,11),data_target[(data_target['Group']==k) & (data_target['piE']==-1)].piEAvg,'k',lw=2,alpha=0.35)
    ax2.plot(np.arange(1,11),data_target[(data_target['Group']==k) & (data_target['piE']==-1)].y,'k',lw=2,alpha=0.35)
    ax3.plot(np.arange(1,11),data_target[(data_target['Group']==k) & (data_target['piE']==-1)].piActual,'k',lw=2,alpha=0.35)
    ax4.plot(np.arange(1,11),data_target[(data_target['Group']==k) & (data_target['piE']==-1)].r,'k',lw=2,alpha=0.35)
    
ax1.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','piEAvg']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax2.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','y']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax3.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','piActual']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax4.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','r']].groupby('Period').mean(),'--k',lw=4,alpha=1)
    
ax1.set_title('Expected inflation $\pi^e$')
ax2.set_title('Output gap $y$')
ax3.set_title('Actual inflation $\pi$')
ax4.set_title('Real interest rate $r$')

ax1.set_xlabel('Period')
ax2.set_xlabel('Period')
ax3.set_xlabel('Period')
ax4.set_xlabel('Period')

ax1.set_ylabel('Percent')
ax2.set_ylabel('Percent')
ax3.set_ylabel('Percent')
ax4.set_ylabel('Percent')

ax1.set_ylim([0,10])
ax2.set_ylim([-25,5])
ax3.set_ylim([-3,8])
ax4.set_ylim([0,25])

fig.tight_layout()

plt.savefig('fig_target_all_groups.png',bbox_inches='tight',dpi=120)

# %%
fig = plt.figure(figsize=(12,8))
ax0 = fig.add_subplot(1,1,1)
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)


ax0.set_frame_on(False)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)
ax0.plot(0, 0,'-k',lw=4,alpha=1)
ax0.plot(0, 0,'--k',lw=4,alpha=1)
lgd = ax0.legend(['dual mandate','inflation target'],ncol=2,fontsize=14,loc=9, bbox_to_anchor=(0.5,-0.1))

ax1.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','piEAvg']].groupby('Period').mean(),'-k',lw=4,alpha=1)
ax2.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','y']].groupby('Period').mean(),'-k',lw=4,alpha=1)
ax3.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','piActual']].groupby('Period').mean(),'-k',lw=4,alpha=1)
ax4.plot(np.arange(1,11),data_dual[(data_dual['piE']==-1)][['Period','r']].groupby('Period').mean(),'-k',lw=4,alpha=1)


ax1.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','piEAvg']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax2.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','y']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax3.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','piActual']].groupby('Period').mean(),'--k',lw=4,alpha=1)
ax4.plot(np.arange(1,11),data_target[(data_target['piE']==-1)][['Period','r']].groupby('Period').mean(),'--k',lw=4,alpha=1)
    
ax1.set_title('Expected inflation $\pi^e$')
ax2.set_title('Output gap $y$')
ax3.set_title('Actual inflation $\pi$')
ax4.set_title('Rate interest rate $r$')

ax1.set_xlabel('Period')
ax2.set_xlabel('Period')
ax3.set_xlabel('Period')
ax4.set_xlabel('Period')

ax1.set_ylabel('Percent')
ax2.set_ylabel('Percent')
ax3.set_ylabel('Percent')
ax4.set_ylabel('Percent')

ax1.set_ylim([2,6])
ax3.set_ylim([2,6])




fig.tight_layout()

plt.savefig('fig_dual_and_target.png',bbox_inches='tight',dpi=120)

# %% [markdown]
# # Plot average central bank loss for both regimes

# %%
data_dual_cb = data_dual[data_dual['piE']==-1].copy()
data_target_cb = data_target[data_target['piE']==-1].copy()

data_dual_cb['Loss'] = (data_dual_cb['piActual']-piStar)**2 + lambd_dual*data_dual_cb['y']**2
data_target_cb['Loss'] = (data_target_cb['piActual']-piStar)**2 + lambd_dual*data_target_cb['y']**2


loss_dual = data_dual_cb[['Period','Loss']].groupby('Period').mean()
loss_target = data_target_cb[['Period','Loss']].groupby('Period').mean()

fig = plt.figure(figsize=(6,4))
ax1 = fig.add_subplot(1,1,1)

ax1.plot(np.arange(1,11),loss_dual,'-k',lw=4,alpha=1)
ax1.plot(np.arange(1,11),loss_target,'--k',lw=4,alpha=1)
    
ax1.set_title('Central bank loss')
ax1.legend(['dual mandate','inflation target'],loc='center left',ncol=1, bbox_to_anchor=(1, 0.5),fontsize=14)

fig.tight_layout()
plt.savefig('fig_dual_and_target_loss.png',bbox_inches='tight',dpi=120)

# %%
data_dual_priv = data_dual[data_dual['piE']!=-1].copy()
data_target_priv = data_target[data_target['piE']!=-1].copy()

# data_dual_priv['Error'] = data_dual_priv.piEAvg - data_dual_priv.piActual
# data_target_priv['Error'] = data_target_priv.piEAvg - data_target_priv.piActual

groups_dual = data_dual_priv.Group.unique()
groups_target = data_target_priv.Group.unique()

figsize = (6,4)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)


ax.plot(data_target_priv[['Period','Error']].groupby('Period').mean(),'k',lw=4,label='All groups')
for g,group_number in enumerate(groups_target):

    ax.plot(data_target_priv[data_target_priv['Group']==group_number][['Period','Error']].groupby('Period').mean(),'k',lw=2,alpha=0.25,label='indiv. groups')
    if g == 0:
        ax.legend(loc='center left',ncol=1, bbox_to_anchor=(1, 0.5),fontsize=14)



ax.set_title('$\pi^e - \pi$')
ax.set_ylim([-1,5])
ax.set_ylabel('Percent')
ax.set_xlabel('Period')

fig.tight_layout()
plt.savefig('fig_forecast_error_target.png',bbox_inches='tight',dpi=120)


figsize = (6,4)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)


ax.plot(data_dual_priv[['Period','Error']].groupby('Period').mean(),'k',lw=4,label='All groups')

for g,group_number in enumerate(groups_dual):

    ax.plot(data_dual_priv[data_dual_priv['Group']==group_number][['Period','Error']].groupby('Period').mean(),'k',lw=2,alpha=0.25,label='indiv. groups')
    if g == 0:
        ax.legend(loc='center left',ncol=1, bbox_to_anchor=(1, 0.5),fontsize=14)




ax.set_title('$\pi^e - \pi$')
ax.set_ylim([-1,5])
ax.set_ylabel('Percent')
ax.set_xlabel('Period')

fig.tight_layout()
plt.savefig('fig_forecast_error_dual.png',bbox_inches='tight',dpi=120)

# %%
def plot_group(group_number,which,filename=None,ylim1=None,ylim2=None,ylim3=None):
    
    if which == 'dual':
        frame = data_dual
        
    else:
        frame = data_target
            

    fig = plt.figure(figsize=(12,16))

    ax0 = fig.add_subplot(1,1,1)
    ax1 = fig.add_subplot(4,1,1)
    ax2 = fig.add_subplot(4,1,2)
    ax3 = fig.add_subplot(4,1,3)
    ax4 = fig.add_subplot(4,1,4)
    
    ax0.set_frame_on(False)
    ax0.get_xaxis().set_visible(False)
    ax0.get_yaxis().set_visible(False)
    ax0.plot(0, 0,'-k',lw=4,alpha=1)
    ax0.plot(0, 0,':k',lw=3,alpha=1)
    ax0.plot(0, 0,'--k',lw=3,alpha=1)
#     lgd = ax0.legend(['individual groups','average across groups'],fontsize=12,loc='upper center', bbox_to_anchor=(0.5,-0.1))
    ax0.legend(['actual','optimal on $\pi^e$','optimal RE'],loc='upper center',bbox_to_anchor=(0.5,-0.1), ncol=3,fontsize=14)



    ax1.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['r'],'-k',lw=4)
    ax1.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['rOpt'],':k',lw=3)
    ax1.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['rRE'],'--k',lw=3)

    ax2.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['piActual'],'-k',lw=4,label='actual')
    ax2.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['piOpt'],':k',lw=3,label='optimal on $\pi^e$')
    ax2.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['piRE'],'--k',lw=3,label='optimal RE')

    ax3.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['y'],'-k',lw=4)
    ax3.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['yOpt'],':k',lw=3)
    ax3.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['yRE'],'--k',lw=3)
    
    ax4.plot(np.arange(1,11),frame[(frame['Group']==group_number) & (frame['piE']==-1)]['Error'],'-k',lw=3)
    
    if ylim1 !=None:
        ax1.set_ylim(ylim1)
    if ylim1 !=None:
        ax2.set_ylim(ylim2)
    if ylim1 !=None:
        ax3.set_ylim(ylim3)
        
    ax1.set_xlabel('Period')
    ax2.set_xlabel('Period')
    ax3.set_xlabel('Period')
    ax4.set_xlabel('Period')
    
    ax1.set_ylabel('Percent')
    ax2.set_ylabel('Percent')
    ax3.set_ylabel('Percent')
    ax4.set_ylabel('Percent')
    
    ax1.set_title('Real interest $r$')
    ax2.set_title('Inflation $\pi$')
    ax3.set_title('Output gap $y$')
    ax4.set_title('Inflation forecast error $\pi^e - \pi$')
    

#     ax2.legend(loc='center left',ncol=1, bbox_to_anchor=(1, 0.5),fontsize=12)
    
    plt.tight_layout()
    
    plt.savefig(filename,bbox_inches='tight',dpi=120)

# %%
plot_group(group_number=6,which='target',filename='fig_target_group_6.png')

# %%
plot_group(group_number=10,which='dual',filename='fig_dual_group_10.png')

# %% [markdown]
# # Make tables with RMSE stats

# %%
data = pd.concat([data_dual,data_target],axis=0).sort_values('Period')
data = data.reset_index(drop=True)

data = data[data['piE']==-1]

def compute_rmse(df,key1,key2):

    periods1_5 = ((df[df['Period']<6][key1] - df[df['Period']<6][key2])**2).mean()**0.5
    periods6_10 = ((df[df['Period']>=5][key1] - df[df['Period']>=5][key2])**2).mean()**0.5
    periods_all = ((df[key1] - df[key2])**2).mean()**0.5
    
    return periods1_5, periods6_10, periods_all

# %%
key1,key2 = ['piEAvg','piActual']

rmse_dual = compute_rmse(data_dual,key1,key2)
rmse_target = compute_rmse(data_target,key1,key2)
rmse_both = compute_rmse(data,key1,key2)


with open('table_rmse_inflation.tex', 'w') as nf:

    nf.write('\\begin{tabular}{r|ccc} & Dual Mandate & Inflation target \\\\\\hline\n\\\\\n')
    nf.write('Periods 1--5 & '+str(round(rmse_dual[0],2))+' & '+str(round(rmse_target[0],2))+'  \\\\\n\\\\\n')
    nf.write('Periods 6--10 & '+str(round(rmse_dual[1],2))+' & '+str(round(rmse_target[1],2))+'  \\\\\\\\\hline\\\\\n')
#     nf.write('All periods & '+str(round(rmse_dual[2],2))+' & '+str(round(rmse_target[2],2))+'  \\\\\\\\\n')
    nf.write('\\end{tabular}')
    
key1,key2 = ['r','rOpt']

rmse_dual = compute_rmse(data_dual,key1,key2)
rmse_target = compute_rmse(data_target,key1,key2)
rmse_both = compute_rmse(data,key1,key2)


with open('table_rmse_interest_opt.tex', 'w') as nf:

    nf.write('\\begin{tabular}{r|ccc} & Dual Mandate & Inflation target \\\\\\hline\n\\\\\n')
    nf.write('Periods 1--5 & '+str(round(rmse_dual[0],2))+' & '+str(round(rmse_target[0],2))+'  \\\\\n\\\\\n')
    nf.write('Periods 6--10 & '+str(round(rmse_dual[1],2))+' & '+str(round(rmse_target[1],2))+'  \\\\\n')#\\hline\\\\\n')
#     nf.write('All periods & '+str(round(rmse_dual[2],2))+' & '+str(round(rmse_target[2],2))+'  \\\\\\\\\n')
    nf.write('\\end{tabular}')

key1,key2 = ['r','rRE']

rmse_dual = compute_rmse(data_dual,key1,key2)
rmse_target = compute_rmse(data_target,key1,key2)
rmse_both = compute_rmse(data,key1,key2)


with open('table_rmse_interest_RE.tex', 'w') as nf:

    nf.write('\\begin{tabular}{r|ccc} & Dual Mandate & Inflation target \\\\\\hline\n\\\\\n')
    nf.write('Periods 1--5 & '+str(round(rmse_dual[0],2))+' & '+str(round(rmse_target[0],2))+'  \\\\\n\\\\\n')
    nf.write('Periods 6--10 & '+str(round(rmse_dual[1],2))+' & '+str(round(rmse_target[1],2))+'  \\\\\n')#\\hline\\\\\n')
#     nf.write('All periods & '+str(round(rmse_dual[2],2))+' & '+str(round(rmse_target[2],2))+'  \\\\\\\\\n')
    nf.write('\\end{tabular}')
    
key1,key2 = ['y','yOpt']

rmse_dual = compute_rmse(data_dual,key1,key2)
rmse_target = compute_rmse(data_target,key1,key2)
rmse_both = compute_rmse(data,key1,key2)

with open('table_rmse_output_opt.tex', 'w') as nf:

    nf.write('\\begin{tabular}{r|ccc} & Dual Mandate & Inflation target \\\\\\hline\n\\\\\n')
    nf.write('Periods 1--5 & '+str(round(rmse_dual[0],2))+' & '+str(round(rmse_target[0],2))+'  \\\\\n\\\\\n')
    nf.write('Periods 6--10 & '+str(round(rmse_dual[1],2))+' & '+str(round(rmse_target[1],2))+'  \\\\\n')#\\hline\\\\\n')
#     nf.write('All periods & '+str(round(rmse_dual[2],2))+' & '+str(round(rmse_target[2],2))+'  \\\\\\\\\n')
    nf.write('\\end{tabular}')
    
key1,key2 = ['y','Zero']

rmse_dual = compute_rmse(data_dual,key1,key2)
rmse_target = compute_rmse(data_target,key1,key2)
rmse_both = compute_rmse(data,key1,key2)

with open('table_rmse_output_RE.tex', 'w') as nf:

    nf.write('\\begin{tabular}{r|ccc} & Dual Mandate & Inflation target \\\\\\hline\n\\\\\n')
    nf.write('Periods 1--5 & '+str(round(rmse_dual[0],2))+' & '+str(round(rmse_target[0],2))+'  \\\\\n\\\\\n')
    nf.write('Periods 6--10 & '+str(round(rmse_dual[1],2))+' & '+str(round(rmse_target[1],2))+'  \\\\\n')#\\hline\\\\\n')
#     nf.write('All periods & '+str(round(rmse_dual[2],2))+' & '+str(round(rmse_target[2],2))+'  \\\\\\\\\n')
    nf.write('\\end{tabular}')

# %%
for g in range(11):
    print('Group',g+1)
    plot_group(group_number=g+1,which='dual',filename='fig_dual_group_'+str(g+1)+'.png')
# Out:
# Group 1
# Group 2
# Group 3
# Group 4
# Group 5
# Group 6
# Group 7
# Group 8
# Group 9
# Group 10
# Group 11

# %%
for g in range(14):
    print('Group',g+1)
    plot_group(group_number=g+1,which='target',filename='fig_target_group_'+str(g+1)+'.png')
# Out:
# Group 1
# Group 2
# Group 3
# Group 4
# Group 5
# Group 6
# Group 7
# Group 8
# Group 9
# Group 10
# Group 11
# Group 12
# Group 13
# Group 14

# %%
# def compute_rmse_for_utest(df,regime):
    
#     piEAvg_piActual = []
#     r_rOpt = []
#     r_rRE = []
#     y_yOpt = []
#     y_Zero = []

#     for period in pd.unique(df.Period):
        

#         key1,key2 = ['piEAvg','piActual']
#         piEAvg_piActual.append(((df[df.Period==period][key1] - df[df.Period==period][key2])**2).mean()**0.5)

#         key1,key2 = ['r','rOpt']
#         r_rOpt.append(((df[df.Period==period][key1] - df[df.Period==period][key2])**2).mean()**0.5)

#         key1,key2 = ['r','rRE']
#         r_rRE.append(((df[df.Period==period][key1] - df[df.Period==period][key2])**2).mean()**0.5)

#         key1,key2 = ['y','yOpt']
#         y_yOpt.append(((df[df.Period==period][key1] - df[df.Period==period][key2])**2).mean()**0.5)

#         key1,key2 = ['y','Zero']
#         y_Zero.append(((df[df.Period==period][key1] - df[df.Period==period][key2])**2).mean()**0.5)

        
#     return pd.DataFrame({'piEAvg_piActual_'+regime:piEAvg_piActual,
#                              'r_rOpt_'+regime:r_rOpt,
#                              'r_rRE_'+regime:r_rRE,
#                              'y_yOpt_'+regime:y_yOpt,
#                              'y_Zero_'+regime:y_Zero},index = pd.unique(df.Period))

# %%
# rmse_dual = compute_rmse_for_utest(data_dual[data_dual.piE==-1],regime='dual')
# rmse_target = compute_rmse_for_utest(data_target[data_target.piE==-1],regime='target')

# data = pd.concat([rmse_dual,rmse_target],axis=1)
# data = data[data.columns.sort_values()]
# data.to_csv('rmse_data.csv',index_label='Period')

# %% [markdown]
# # csv file for U-test on CB loss

# %%
data_dual_cb = data_dual_cb.sort_values('Group')
data_target_cb = data_target_cb.sort_values('Group')

data_dual_cb['Regime'] = 'Dual'
data_target_cb['Regime'] = 'Target'

col_1_5 = np.array([])
col_6_10 = np.array([])
col_all = np.array([])

col_group = np.array([])
col_regime = np.array([])

col_group = np.append(col_group,data_dual_cb['Group'].unique())
col_group = np.append(col_group,data_target_cb['Group'].unique())

col_regime = np.append(col_regime,data_dual_cb[data_dual_cb.Period ==1].Regime)
col_regime = np.append(col_regime,data_target_cb[data_target_cb.Period ==1].Regime)


col_1_5 = np.append(col_1_5,data_dual_cb[data_dual_cb.Period<6].groupby('Group').mean().Loss.values)
col_1_5 = np.append(col_1_5,data_target_cb[data_target_cb.Period<6].groupby('Group').mean().Loss.values)

col_6_10 = np.append(col_6_10,data_dual_cb[data_dual_cb.Period>5].groupby('Group').mean().Loss.values)
col_6_10 = np.append(col_6_10,data_target_cb[data_target_cb.Period>5].groupby('Group').mean().Loss.values)

col_all = np.append(col_all,data_dual_cb.groupby('Group').mean().Loss.values)
col_all = np.append(col_all,data_target_cb.groupby('Group').mean().Loss.values)


df = pd.DataFrame({'Regime':col_regime,'Group':col_group,'Periods_1-5':col_1_5,'Periods_6-10':col_6_10,'All_Periods':col_all})
df= df[['Regime','Group','Periods_1-5','Periods_6-10','All_Periods']]
df.to_csv('utest_data_cb_loss.csv',index=False)

# %% [markdown]
# # csv files for U-test on RMSEs for endogenous variables

# %%
def compute_rmse_for_utest(data_dual_cb,data_target_cb,key,filename):
    
    data_dual_cb['Regime'] = 'Dual'
    data_target_cb['Regime'] = 'Target'

    col_1_5 = np.array([])
    col_6_10 = np.array([])
    col_all = np.array([])

    col_group = np.array([])
    col_regime = np.array([])

    col_group = np.append(col_group,data_dual_cb['Group'].unique())
    col_group = np.append(col_group,data_target_cb['Group'].unique())

    col_regime = np.append(col_regime,data_dual_cb[data_dual_cb.Period ==1].Regime)
    col_regime = np.append(col_regime,data_target_cb[data_target_cb.Period ==1].Regime)
    
    
    col_1_5 = np.append(col_1_5,np.sqrt(data_dual_cb[data_dual_cb.Period<6][['Group',key]].groupby('Group').sum()).values)
    col_1_5 = np.append(col_1_5,np.sqrt(data_target_cb[data_target_cb.Period<6][['Group',key]].groupby('Group').sum()).values)
    
    col_6_10 = np.append(col_6_10,np.sqrt(data_dual_cb[data_dual_cb.Period>5][['Group',key]].groupby('Group').sum()).values)
    col_6_10 = np.append(col_6_10,np.sqrt(data_target_cb[data_target_cb.Period>5][['Group',key]].groupby('Group').sum()).values)
    
    col_all = np.append(col_all,np.sqrt(data_dual_cb[['Group',key]].groupby('Group').sum()).values)
    col_all = np.append(col_all,np.sqrt(data_target_cb[['Group',key]].groupby('Group').sum()).values)

    df = pd.DataFrame({'Regime':col_regime,'Group':col_group,'Periods_1-5':col_1_5,'Periods_6-10':col_6_10,'All_Periods':col_all})
    df= df[['Regime','Group','Periods_1-5','Periods_6-10','All_Periods']]

    df.to_csv(filename,index=False)

# %%
data_dual_cb['piE_pi2'] = (data_dual_cb['piEAvg'] - data_dual_cb['piActual'])**2
data_dual_cb['r_rOpt2'] = (data_dual_cb['r'] - data_dual_cb['rOpt'])**2
data_dual_cb['r_rRE2'] = (data_dual_cb['r'] - data_dual_cb['rRE'])**2
data_dual_cb['y_yOpt2'] = (data_dual_cb['y'] - data_dual_cb['yOpt'])**2
data_dual_cb['y_yRE2'] = (data_dual_cb['y'] - data_dual_cb['yRE'])**2

data_target_cb['piE_pi2'] = (data_target_cb['piEAvg'] - data_target_cb['piActual'])**2
data_target_cb['r_rOpt2'] = (data_target_cb['r'] - data_target_cb['rOpt'])**2
data_target_cb['r_rRE2'] = (data_target_cb['r'] - data_target_cb['rRE'])**2
data_target_cb['y_yOpt2'] = (data_target_cb['y'] - data_target_cb['yOpt'])**2
data_target_cb['y_yRE2'] = (data_target_cb['y'] - data_target_cb['yRE'])**2


compute_rmse_for_utest(data_dual_cb,data_target_cb,key='piE_pi2',filename='utest_data_1_piE_pi.csv')
compute_rmse_for_utest(data_dual_cb,data_target_cb,key='r_rOpt2',filename='utest_data_2_r_rOpt.csv')
compute_rmse_for_utest(data_dual_cb,data_target_cb,key='r_rRE2',filename='utest_data_3_r_rRE.csv')
compute_rmse_for_utest(data_dual_cb,data_target_cb,key='y_yOpt2',filename='utest_data_4_y_yOpt.csv')
compute_rmse_for_utest(data_dual_cb,data_target_cb,key='y_yRE2',filename='utest_data_5_y_yRE.csv')
